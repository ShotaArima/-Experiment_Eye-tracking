# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# %% [markdown]
# # user-1

# %%
df_1 = pd.read_csv("/content/drive/MyDrive/class/情報デザイン論/加工データ csv/user-1.csv")
df_1.head()
# Out:
#    Recording timestamp  Computer timestamp       Sensor Project name  \
# 0                    0          6405043858          NaN          JD4
# 1                 8506          6405052364        Mouse          JD4
# 2                18053          6405061911  Eye Tracker          JD4
# 3                24203          6405068061        Mouse          JD4
# 4                39987          6405083845        Mouse          JD4
#
#   Export date Participant name Recording name Recording date  \
# 0  2025/07/18           user-1     Recording2     2025/07/18
# 1  2025/07/18           user-1     Recording2     2025/07/18
# 2  2025/07/18           user-1     Recording2     2025/07/18
# 3  2025/07/18           user-1     Recording2     2025/07/18
# 4  2025/07/18           user-1     Recording2     2025/07/18
#
#   Recording date UTC Recording start time  ...  \
# 0         2025/07/18         16:09:36.966  ...
# 1         2025/07/18         16:09:36.966  ...
# ...

# %%
df_1.describe()
# Out:
#        Recording timestamp  Computer timestamp  Recording duration  \
# count         1.188800e+04        1.188800e+04             11888.0
# mean          1.132475e+08        6.518291e+09            214788.0
# std           6.015674e+07        6.015674e+07                 0.0
# min           0.000000e+00        6.405044e+09            214788.0
# 25%           6.540577e+07        6.470450e+09            214788.0
# 50%           1.147756e+08        6.519819e+09            214788.0
# 75%           1.643553e+08        6.569399e+09            214788.0
# max           2.147884e+08        6.619832e+09            214788.0
#
#        Recording resolution height  Recording resolution width  \
# count                      11888.0                     11888.0
# mean                        1080.0                      1920.0
# std                            0.0                         0.0
# min                         1080.0                      1920.0
# ...

# %%
df_1.isnull().all()
null_columns_1 = df_1.columns[df_1.isnull().all()]
print(null_columns_1)
# Out:
# Index(['Average calibration precision SD (mm)',
#        'Average calibration precision RMS (mm)',
#        'Average calibration precision SD (degrees)',
#        'Average calibration precision RMS (degrees)',
#        'Average calibration precision SD (pixels)',
#        'Average calibration precision RMS (pixels)', 'Ungrouped',
#        'Client area position X (DACSpx)', 'Client area position Y (DACSpx)',
#        'Viewport position X', 'Viewport position Y', 'Viewport width',
#        'Viewport height', 'Full page width', 'Full page height'],
#       dtype='object')

# %% [markdown]
# # user-2

# %%
df_2 = pd.read_csv("/content/drive/MyDrive/class/情報デザイン論/加工データ csv/user-2.csv")
df_2.head()
# Out:
#    Recording timestamp  Computer timestamp       Sensor Project name  \
# 0                    0          6658954021          NaN          JD4
# 1                10996          6658965017        Mouse          JD4
# 2                14613          6658968634  Eye Tracker          JD4
# 3                31732          6658985753  Eye Tracker          JD4
# 4                32277          6658986298        Mouse          JD4
#
#   Export date Participant name Recording name Recording date  \
# 0  2025/07/18           user-2     Recording3     2025/07/18
# 1  2025/07/18           user-2     Recording3     2025/07/18
# 2  2025/07/18           user-2     Recording3     2025/07/18
# 3  2025/07/18           user-2     Recording3     2025/07/18
# 4  2025/07/18           user-2     Recording3     2025/07/18
#
#   Recording date UTC Recording start time  ...  \
# 0         2025/07/18         16:13:50.955  ...
# 1         2025/07/18         16:13:50.955  ...
# ...

# %%
df_2.describe()
# Out:
#        Recording timestamp  Computer timestamp  Recording duration  \
# count         1.635400e+04        1.635400e+04             16354.0
# mean          1.444289e+08        6.803383e+09            286004.0
# std           8.454120e+07        8.454120e+07                 0.0
# min           0.000000e+00        6.658954e+09            286004.0
# 25%           6.837724e+07        6.727331e+09            286004.0
# 50%           1.501182e+08        6.809072e+09            286004.0
# 75%           2.174356e+08        6.876390e+09            286004.0
# max           2.860039e+08        6.944958e+09            286004.0
#
#        Recording resolution height  Recording resolution width  \
# count                      16354.0                     16354.0
# mean                        1080.0                      1920.0
# std                            0.0                         0.0
# min                         1080.0                      1920.0
# ...

# %%
df_2.isnull().all()
null_columns_2 = df_2.columns[df_2.isnull().all()]
print(null_columns_2)
# Out:
# Index(['Average calibration precision SD (mm)',
#        'Average calibration precision RMS (mm)',
#        'Average calibration precision SD (degrees)',
#        'Average calibration precision RMS (degrees)',
#        'Average calibration precision SD (pixels)',
#        'Average calibration precision RMS (pixels)', 'Ungrouped',
#        'Client area position X (DACSpx)', 'Client area position Y (DACSpx)',
#        'Viewport position X', 'Viewport position Y', 'Viewport width',
#        'Viewport height', 'Full page width', 'Full page height'],
#       dtype='object')

# %% [markdown]
# # user-3

# %%
df_3 = pd.read_csv("/content/drive/MyDrive/class/情報デザイン論/加工データ csv/user-3.csv")
df_3.head()
# Out:
#    Recording timestamp  Computer timestamp       Sensor Project name  \
# 0                    0          7007053259          NaN          JD4
# 1                18876          7007072135  Eye Tracker          JD4
# 2                35303          7007088562  Eye Tracker          JD4
# 3                51944          7007105203  Eye Tracker          JD4
# 4                68932          7007122191  Eye Tracker          JD4
#
#   Export date Participant name Recording name Recording date  \
# 0  2025/07/18           user-3     Recording4     2025/07/18
# 1  2025/07/18           user-3     Recording4     2025/07/18
# 2  2025/07/18           user-3     Recording4     2025/07/18
# 3  2025/07/18           user-3     Recording4     2025/07/18
# 4  2025/07/18           user-3     Recording4     2025/07/18
#
#   Recording date UTC Recording start time  ...  \
# 0         2025/07/18         16:19:39.048  ...
# 1         2025/07/18         16:19:39.048  ...
# ...

# %%
df_3.describe()
# Out:
#        Recording timestamp  Computer timestamp  Recording duration  \
# count         1.743900e+04        1.743900e+04             17439.0
# mean          1.553534e+08        7.162407e+09            307137.0
# std           9.058494e+07        9.058494e+07                 0.0
# min           0.000000e+00        7.007053e+09            307137.0
# 25%           7.346719e+07        7.080520e+09            307137.0
# 50%           1.619376e+08        7.168991e+09            307137.0
# 75%           2.344653e+08        7.241519e+09            307137.0
# max           3.071370e+08        7.314190e+09            307137.0
#
#        Recording resolution height  Recording resolution width  \
# count                      17439.0                     17439.0
# mean                        1080.0                      1920.0
# std                            0.0                         0.0
# min                         1080.0                      1920.0
# ...

# %%
df_3.isnull().all()
null_columns_3 = df_3.columns[df_3.isnull().all()]
print(null_columns_3)
# Out:
# Index(['Average calibration precision SD (mm)',
#        'Average calibration precision RMS (mm)',
#        'Average calibration precision SD (degrees)',
#        'Average calibration precision RMS (degrees)',
#        'Average calibration precision SD (pixels)',
#        'Average calibration precision RMS (pixels)', 'Ungrouped',
#        'Client area position X (DACSpx)', 'Client area position Y (DACSpx)',
#        'Viewport position X', 'Viewport position Y', 'Viewport width',
#        'Viewport height', 'Full page width', 'Full page height'],
#       dtype='object')

# %% [markdown]
# # user-4

# %%
df_4 = pd.read_csv("/content/drive/MyDrive/class/情報デザイン論/加工データ csv/user-4.csv")
df_4.head()
# Out:
#    Recording timestamp  Computer timestamp       Sensor Project name  \
# 0                    0           120673071          NaN          JD4
# 1                19906           120692977  Eye Tracker          JD4
# 2                76745           120749816  Eye Tracker          JD4
# 3                93388           120766459  Eye Tracker          JD4
# 4               110076           120783147  Eye Tracker          JD4
#
#   Export date Participant name Recording name Recording date  \
# 0  2025/07/18           user-4     Recording5     2025/07/18
# 1  2025/07/18           user-4     Recording5     2025/07/18
# 2  2025/07/18           user-4     Recording5     2025/07/18
# 3  2025/07/18           user-4     Recording5     2025/07/18
# 4  2025/07/18           user-4     Recording5     2025/07/18
#
#   Recording date UTC Recording start time  ...  \
# 0         2025/07/18         16:30:57.621  ...
# 1         2025/07/18         16:30:57.621  ...
# ...

# %%
df_4.describe()
# Out:
#        Recording timestamp  Computer timestamp  Recording duration  \
# count         1.087300e+04        1.087300e+04             10873.0
# mean          1.013925e+08        2.220656e+08            194658.0
# std           5.531268e+07        5.531268e+07                 0.0
# min           0.000000e+00        1.206731e+08            194658.0
# 25%           5.821435e+07        1.788874e+08            194658.0
# 50%           1.033619e+08        2.240349e+08            194658.0
# 75%           1.486007e+08        2.692738e+08            194658.0
# max           1.946582e+08        3.153312e+08            194658.0
#
#        Recording resolution height  Recording resolution width  \
# count                      10873.0                     10873.0
# mean                        1080.0                      1920.0
# std                            0.0                         0.0
# min                         1080.0                      1920.0
# ...

# %%
df_4.isnull().all()
null_columns_4 = df_4.columns[df_4.isnull().all()]
print(null_columns_4)
# Out:
# Index(['Average calibration precision SD (mm)',
#        'Average calibration precision RMS (mm)',
#        'Average calibration precision SD (degrees)',
#        'Average calibration precision RMS (degrees)',
#        'Average calibration precision SD (pixels)',
#        'Average calibration precision RMS (pixels)', 'Ungrouped',
#        'Client area position X (DACSpx)', 'Client area position Y (DACSpx)',
#        'Viewport position X', 'Viewport position Y', 'Viewport width',
#        'Viewport height', 'Full page width', 'Full page height'],
#       dtype='object')

# %% [markdown]
# # user-5

# %%
df_5 = pd.read_csv("/content/drive/MyDrive/class/情報デザイン論/加工データ csv/user-5.csv")
df_5.head()
# Out:
# /tmp/ipython-input-14-1236479400.py:1: DtypeWarning: Columns (73) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_5 = pd.read_csv("/content/drive/MyDrive/class/情報デザイン論/加工データ csv/user-5.csv")
#    Recording timestamp  Computer timestamp       Sensor Project name  \
# 0                    0           327258000          NaN          JD4
# 1                 9016           327267016        Mouse          JD4
# 2                14166           327272166  Eye Tracker          JD4
# 3                24233           327282233        Mouse          JD4
# 4                31285           327289285  Eye Tracker          JD4
#
#   Export date Participant name Recording name Recording date  \
# 0  2025/07/18           user-5     Recording6     2025/07/18
# 1  2025/07/18           user-5     Recording6     2025/07/18
# 2  2025/07/18           user-5     Recording6     2025/07/18
# 3  2025/07/18           user-5     Recording6     2025/07/18
# ...

# %%
df_5.describe()
# Out:
#        Recording timestamp  Computer timestamp  Recording duration  \
# count         1.749200e+04        1.749200e+04             17492.0
# mean          1.561094e+08        4.833674e+08            309213.0
# std           9.146784e+07        9.146784e+07                 0.0
# min           0.000000e+00        3.272580e+08            309213.0
# 25%           7.415635e+07        4.014143e+08            309213.0
# 50%           1.636886e+08        4.909466e+08            309213.0
# 75%           2.362889e+08        5.635469e+08            309213.0
# max           3.092126e+08        6.364706e+08            309213.0
#
#        Recording resolution height  Recording resolution width  \
# count                      17492.0                     17492.0
# mean                        1080.0                      1920.0
# std                            0.0                         0.0
# min                         1080.0                      1920.0
# ...

# %%
df_5.isnull().all()
null_columns_5 = df_5.columns[df_5.isnull().all()]
print(null_columns_5)
# Out:
# Index(['Average calibration precision SD (mm)',
#        'Average calibration precision RMS (mm)',
#        'Average calibration precision SD (degrees)',
#        'Average calibration precision RMS (degrees)',
#        'Average calibration precision SD (pixels)',
#        'Average calibration precision RMS (pixels)', 'Ungrouped',
#        'Client area position X (DACSpx)', 'Client area position Y (DACSpx)',
#        'Viewport position X', 'Viewport position Y', 'Viewport width',
#        'Viewport height', 'Full page width', 'Full page height'],
#       dtype='object')

# %% [markdown]
# # user-6

# %%
df_6 = pd.read_csv("/content/drive/MyDrive/class/情報デザイン論/加工データ csv/user-6.csv")
df_6.head()
# Out:
#    Recording timestamp  Computer timestamp       Sensor Project name  \
# 0                    0           843115863          NaN          JD4
# 1                12473           843128336        Mouse          JD4
# 2                18888           843134751  Eye Tracker          JD4
# 3                27002           843142865        Mouse          JD4
# 4                43069           843158932        Mouse          JD4
#
#   Export date Participant name Recording name Recording date  \
# 0  2025/07/18           user-6     Recording7     2025/07/18
# 1  2025/07/18           user-6     Recording7     2025/07/18
# 2  2025/07/18           user-6     Recording7     2025/07/18
# 3  2025/07/18           user-6     Recording7     2025/07/18
# 4  2025/07/18           user-6     Recording7     2025/07/18
#
#   Recording date UTC Recording start time  ...  \
# 0         2025/07/18         16:43:00.114  ...
# 1         2025/07/18         16:43:00.114  ...
# ...

# %%
df_6.describe()
# Out:
#        Recording timestamp  Computer timestamp  Recording duration  \
# count         1.102100e+04        1.102100e+04             11021.0
# mean          1.054838e+08        9.485997e+08            198601.0
# std           5.532504e+07        5.532504e+07                 0.0
# min           0.000000e+00        8.431159e+08            198601.0
# 25%           6.137096e+07        9.044868e+08            198601.0
# 50%           1.070672e+08        9.501831e+08            198601.0
# 75%           1.527629e+08        9.958787e+08            198601.0
# max           1.986014e+08        1.041717e+09            198601.0
#
#        Recording resolution height  Recording resolution width  \
# count                      11021.0                     11021.0
# mean                        1080.0                      1920.0
# std                            0.0                         0.0
# min                         1080.0                      1920.0
# ...

# %%
df_6.isnull().all()
null_columns_6 = df_6.columns[df_6.isnull().all()]
print(null_columns_6)
# Out:
# Index(['Average calibration precision SD (mm)',
#        'Average calibration precision RMS (mm)',
#        'Average calibration precision SD (degrees)',
#        'Average calibration precision RMS (degrees)',
#        'Average calibration precision SD (pixels)',
#        'Average calibration precision RMS (pixels)', 'Ungrouped',
#        'Client area position X (DACSpx)', 'Client area position Y (DACSpx)',
#        'Viewport position X', 'Viewport position Y', 'Viewport width',
#        'Viewport height', 'Full page width', 'Full page height'],
#       dtype='object')

# %% [markdown]
# # user-7

# %%
df_7 = pd.read_csv("/content/drive/MyDrive/class/情報デザイン論/加工データ csv/user-7.csv")
df_7.head()
# Out:
# /tmp/ipython-input-20-267814551.py:1: DtypeWarning: Columns (38,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_7 = pd.read_csv("/content/drive/MyDrive/class/情報デザイン論/加工データ csv/user-7.csv")
#    Recording timestamp  Computer timestamp       Sensor Project name  \
# 0                    0          1230701762          NaN          JD4
# 1                 7718          1230709480        Mouse          JD4
# 2                18880          1230720642  Eye Tracker          JD4
# 3                23441          1230725203        Mouse          JD4
# 4                39413          1230741175        Mouse          JD4
#
#   Export date Participant name Recording name Recording date  \
# 0  2025/07/18           user-7     Recording8     2025/07/18
# 1  2025/07/18           user-7     Recording8     2025/07/18
# 2  2025/07/18           user-7     Recording8     2025/07/18
# 3  2025/07/18           user-7     Recording8     2025/07/18
# ...

# %%
df_7.describe()
# Out:
#        Recording timestamp  Computer timestamp  Recording duration  \
# count         2.423600e+04        2.423600e+04             24236.0
# mean          2.064555e+08        1.437157e+09            419125.0
# std           1.227688e+08        1.227688e+08                 0.0
# min           0.000000e+00        1.230702e+09            419125.0
# 25%           1.001469e+08        1.330849e+09            419125.0
# 50%           2.016380e+08        1.432340e+09            419125.0
# 75%           3.184622e+08        1.549164e+09            419125.0
# max           4.191247e+08        1.649826e+09            419125.0
#
#        Recording resolution height  Recording resolution width  \
# count                      24236.0                     24236.0
# mean                        1080.0                      1920.0
# std                            0.0                         0.0
# min                         1080.0                      1920.0
# ...

# %%
df_7.isnull().all()
null_columns_7 = df_7.columns[df_7.isnull().all()]
print(null_columns_7)
# Out:
# Index(['Average calibration precision SD (mm)',
#        'Average calibration precision RMS (mm)',
#        'Average calibration precision SD (degrees)',
#        'Average calibration precision RMS (degrees)',
#        'Average calibration precision SD (pixels)',
#        'Average calibration precision RMS (pixels)', 'Ungrouped',
#        'Client area position X (DACSpx)', 'Client area position Y (DACSpx)',
#        'Viewport position X', 'Viewport position Y', 'Viewport width',
#        'Viewport height', 'Full page width', 'Full page height'],
#       dtype='object')

# %% [markdown]
# # user-8

# %%
df_8 = pd.read_csv("/content/drive/MyDrive/class/情報デザイン論/加工データ csv/user-8.csv")
df_8.head()
# Out:
#    Recording timestamp  Computer timestamp       Sensor Project name  \
# 0                    0          1947309808          NaN          JD4
# 1                18932          1947328740  Eye Tracker          JD4
# 2                48708          1947358516        Mouse          JD4
# 3                50278          1947360086  Eye Tracker          JD4
# 4                64522          1947374330        Mouse          JD4
#
#   Export date Participant name Recording name Recording date  \
# 0  2025/07/18           user-8     Recording9     2025/07/18
# 1  2025/07/18           user-8     Recording9     2025/07/18
# 2  2025/07/18           user-8     Recording9     2025/07/18
# 3  2025/07/18           user-8     Recording9     2025/07/18
# 4  2025/07/18           user-8     Recording9     2025/07/18
#
#   Recording date UTC Recording start time  ...  \
# 0         2025/07/18         17:01:24.322  ...
# 1         2025/07/18         17:01:24.322  ...
# ...

# %%
df_8.describe()
# Out:
#        Recording timestamp  Computer timestamp  Recording duration  \
# count         1.075800e+04        1.075800e+04             10758.0
# mean          1.031853e+08        2.050495e+09            194848.0
# std           5.452436e+07        5.452436e+07                 0.0
# min           0.000000e+00        1.947310e+09            194848.0
# 25%           6.007347e+07        2.007383e+09            194848.0
# 50%           1.047419e+08        2.052052e+09            194848.0
# 75%           1.496926e+08        2.097002e+09            194848.0
# max           1.948478e+08        2.142158e+09            194848.0
#
#        Recording resolution height  Recording resolution width  \
# count                      10758.0                     10758.0
# mean                        1080.0                      1920.0
# std                            0.0                         0.0
# min                         1080.0                      1920.0
# ...

# %%
df_8.isnull().all()
null_columns_8 = df_8.columns[df_8.isnull().all()]
print(null_columns_8)
# Out:
# Index(['Average calibration precision SD (mm)',
#        'Average calibration precision RMS (mm)',
#        'Average calibration precision SD (degrees)',
#        'Average calibration precision RMS (degrees)',
#        'Average calibration precision SD (pixels)',
#        'Average calibration precision RMS (pixels)', 'Ungrouped',
#        'Client area position X (DACSpx)', 'Client area position Y (DACSpx)',
#        'Viewport position X', 'Viewport position Y', 'Viewport width',
#        'Viewport height', 'Full page width', 'Full page height'],
#       dtype='object')

# %% [markdown]
# # user-9

# %%
df_9 = pd.read_csv("/content/drive/MyDrive/class/情報デザイン論/加工データ csv/user-9.csv")
df_9.head()
# Out:
#    Recording timestamp  Computer timestamp       Sensor Project name  \
# 0                    0          2267020723          NaN          JD4
# 1                18909          2267039632  Eye Tracker          JD4
# 2                22084          2267042807        Mouse          JD4
# 3                51052          2267071775  Eye Tracker          JD4
# 4                67696          2267088419  Eye Tracker          JD4
#
#   Export date Participant name Recording name Recording date  \
# 0  2025/07/18           user-9    Recording10     2025/07/18
# 1  2025/07/18           user-9    Recording10     2025/07/18
# 2  2025/07/18           user-9    Recording10     2025/07/18
# 3  2025/07/18           user-9    Recording10     2025/07/18
# 4  2025/07/18           user-9    Recording10     2025/07/18
#
#   Recording date UTC Recording start time  ...  \
# 0         2025/07/18         17:06:44.023  ...
# 1         2025/07/18         17:06:44.023  ...
# ...

# %%
df_9.describe()
# Out:
#        Recording timestamp  Computer timestamp  Recording duration  \
# count         1.359300e+04        1.359300e+04             13593.0
# mean          1.271010e+08        2.394122e+09            243039.0
# std           6.816114e+07        6.816114e+07                 0.0
# min           0.000000e+00        2.267021e+09            243039.0
# 25%           7.135926e+07        2.338380e+09            243039.0
# 50%           1.285386e+08        2.395559e+09            243039.0
# 75%           1.854387e+08        2.452459e+09            243039.0
# max           2.430388e+08        2.510059e+09            243039.0
#
#        Recording resolution height  Recording resolution width  \
# count                      13593.0                     13593.0
# mean                        1080.0                      1920.0
# std                            0.0                         0.0
# min                         1080.0                      1920.0
# ...

# %%
df_9.isnull().all()
null_columns_9 = df_9.columns[df_9.isnull().all()]
print(null_columns_9)
# Out:
# Index(['Average calibration precision SD (mm)',
#        'Average calibration precision RMS (mm)',
#        'Average calibration precision SD (degrees)',
#        'Average calibration precision RMS (degrees)',
#        'Average calibration precision SD (pixels)',
#        'Average calibration precision RMS (pixels)', 'Ungrouped',
#        'Client area position X (DACSpx)', 'Client area position Y (DACSpx)',
#        'Viewport position X', 'Viewport position Y', 'Viewport width',
#        'Viewport height', 'Full page width', 'Full page height'],
#       dtype='object')

# %%
# 例示: null_columns_1 ~ null_columns_9 がある場合
null_columns_list = []
for i in range(1, 10):
    null_columns_list.extend(eval(f'null_columns_{i}').tolist())

# ユニークな特徴量名（カラム名）のリスト
unique_features = set(null_columns_list)
print('ユニークな特徴量名リスト：')
print(unique_features)

# 各特徴量名の出現回数
feature_counts = Counter(null_columns_list)
print('\n各特徴量ごとの出現回数：')
for feature, count in feature_counts.items():
    print(f'{feature}: {count}')
# Out:
# ユニークな特徴量名リスト：
# {'Full page height', 'Viewport position Y', 'Viewport width', 'Viewport position X', 'Viewport height', 'Full page width', 'Average calibration precision RMS (pixels)', 'Average calibration precision SD (pixels)', 'Client area position Y (DACSpx)', 'Ungrouped', 'Average calibration precision SD (degrees)', 'Average calibration precision RMS (degrees)', 'Average calibration precision RMS (mm)', 'Client area position X (DACSpx)', 'Average calibration precision SD (mm)'}
#
# 各特徴量ごとの出現回数：
# Average calibration precision SD (mm): 9
# Average calibration precision RMS (mm): 9
# Average calibration precision SD (degrees): 9
# Average calibration precision RMS (degrees): 9
# Average calibration precision SD (pixels): 9
# Average calibration precision RMS (pixels): 9
# Ungrouped: 9
# Client area position X (DACSpx): 9
# Client area position Y (DACSpx): 9
# Viewport position X: 9
# Viewport position Y: 9
# Viewport width: 9
# Viewport height: 9
# Full page width: 9
# ...

# %%
null_cols_list = [
    'Average calibration precision SD (mm)',
    'Average calibration precision RMS (mm)',
    'Average calibration precision SD (degrees)',
    'Average calibration precision RMS (degrees)',
    'Average calibration precision SD (pixels)',
    'Average calibration precision RMS (pixels)',
    'Ungrouped',
    'Client area position X (DACSpx)',
    'Client area position Y (DACSpx)',
    'Viewport position X',
    'Viewport position Y',
    'Viewport width',
    'Viewport height',
    'Full page width',
    'Full page height'
]
for i in range(1, 10):
  # 欠損値カラムだけ取り出す
  exec(f'df_{i}_null = df_{i}[null_cols_list]')
  # df_1_null = df_1[null_cols_list]

  # 残りのカラムだけ取り出す
  exec(f'df_{i}_nonull = df_{i}.drop(columns=null_cols_list)')
  # df_1_nonull = df_1.drop(columns=null_cols_list)

# %%
df_1_nonull.to_csv("/content/drive/MyDrive/class/情報デザイン論/加工データ csv/user-1-nonull.csv")

# %%
for i in range(1, 10):
    eval(f'df_{i}_nonull.to_csv("/content/drive/MyDrive/class/情報デザイン論/加工データ csv/user-{i}-nonull.csv")   ')
