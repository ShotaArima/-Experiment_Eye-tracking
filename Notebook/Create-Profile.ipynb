# %%
! uv pip install ydata_profiling
# Out:
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 105ms

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport
from IPython.display import display, HTML
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
for i in range(9, 10):
  exec(f'df = pd.read_csv("/content/drive/MyDrive/class/情報デザイン論/加工データ csv/user-{i}-nonull.csv")')
  exec(f'profile = ProfileReport(df)')
  exec(f'profile.to_file("/content/drive/MyDrive/class/情報デザイン論/加工データ csv/ProfileReportHTML/titanic_train_data_profile_{i}.html")')
# Out:
# ...
# 100%|██████████| 84/84 [00:03<00:00, 22.18it/s]
# /usr/local/lib/python3.11/dist-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /usr/local/lib/python3.11/dist-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/ydata_profiling/visualisation/utils.py:73: UserWarning: Glyph 35222 (\N{CJK UNIFIED IDEOGRAPH-8996}) missing from font(s) DejaVu Sans.
#   plt.savefig(
# /usr/local/lib/python3.11/dist-packages/ydata_profiling/visualisation/utils.py:73: UserWarning: Glyph 32218 (\N{CJK UNIFIED IDEOGRAPH-7DDA}) missing from font(s) DejaVu Sans.
#   plt.savefig(
# ...
